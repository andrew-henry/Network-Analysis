# %%
import seaborn as sns
import osmnx as ox
ox.config(log_console = True, use_cache = True)
ox.__version__
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

# %%
import geopandas as gpd
import networkx as nx
import requests
from shapely.ops import cascaded_union
from shapely.geometry import Point, Polygon

# %%
West_Palm = ox.graph_from_place('West Palm Beach, Florida, US', network_type='drive')
fig, ax = ox.plot_graph(West_Palm, fig_height = 9)

# %%
Fort_Lauderdale = ox.graph_from_place('Fort Lauderdale, Florida, US', network_type='drive')
fig, ax = ox.plot_graph(Fort_Lauderdale, fig_height = 9)

# %%
Delray = ox.graph_from_place('Delray Beach, Florida, US', network_type='drive')
fig, ax = ox.plot_graph(Delray, fig_height = 9)

# %%
Jupiter = ox.graph_from_place('Jupiter, Florida, US', network_type='drive')
fig, ax = ox.plot_graph(Jupiter, fig_height = 9)

# %%
Miami = ox.graph_from_place('Miami, Florida, US', network_type='drive')
fig, ax = ox.plot_graph(Miami, fig_height = 9)
